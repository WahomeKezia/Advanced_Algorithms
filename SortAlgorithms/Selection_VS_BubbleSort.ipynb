# %%
import matplotlib.pyplot as plt
import numpy as np
import time

# Function to implement Bubble Sort
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

# Function to implement Selection Sort
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i+1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]

# Function to generate data for plotting
def generate_data(func, size):
    data = []
    for n in size:
        arr = np.random.randint(1, 100, n)  # Generate a random array of size n
        start_time = time.time()
        func(arr)
        end_time = time.time()
        elapsed_time = end_time - start_time
        data.append(elapsed_time)
    return data

# Generate input sizes (varying from 10 to 1000)
sizes = np.arange(10, 1001, 10)

# Generate data for Bubble Sort and Selection Sort
bubble_sort_data = generate_data(bubble_sort, sizes)
selection_sort_data = generate_data(selection_sort, sizes)

# Plotting the graphs
plt.plot(sizes, bubble_sort_data, label='Bubble Sort')
plt.plot(sizes, selection_sort_data, label='Selection Sort')
plt.xlabel('Input Size (n)')
plt.ylabel('Running Time')
plt.legend()
plt.show()
